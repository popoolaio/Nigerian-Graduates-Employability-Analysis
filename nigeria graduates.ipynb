# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
n_grad=pd.read_csv('Nigerian Graduates.csv')

# %%
n_grad
# Out:
#                Timestamp What is your gender  Year of graduation  \
# 0       2/8/2018 9:05:23                Male                2013
# 1     2/15/2018 12:11:32                Male                2014
# 2     2/15/2018 13:47:10              Female                2013
# 3     2/16/2018 13:01:34                Male                2017
# 4     2/16/2018 13:18:03              Female                2013
# ...                  ...                 ...                 ...
# 5214  5/14/2018 19:51:56              Female                2014
# 5215  5/15/2018 10:17:12              Female                2017
# 5216  5/15/2018 10:33:45              Female                2014
# 5217  5/15/2018 13:49:47              Female                2015
# 5218  5/15/2018 23:39:09                Male                2016
#
#                                 Title of course studied  \
# 0                   Electrical & Electronic Engineering
# 1                                            Psychology
# ...

# %%
sns.countplot(x='What is your gender',data=n_grad)

# %%
n_grad.count()
# Out:
# Timestamp                                                                                                                       5219
# What is your gender                                                                                                             5219
# Year of graduation                                                                                                              5219
# Title of course studied                                                                                                         5219
# Polytechnic/University attended                                                                                                 5219
# What is your highest level of education?                                                                                        5219
# What best describes your current status?                                                                                        5219
# ...

# %%
n_grad.shape
# Out:
# (5219, 36)

# %%
n_grad.drop('Thinking about your first employment after graduation, what was your job level?',axis=1,inplace=True)

# %%
n_grad.drop('How many jobs have you had since graduation including your current one?',axis=1,inplace=True)

# %%
n_grad.drop(['What currency are you currently paid in?','Approximately how many hours a day do you currently work?'],axis=1,inplace=True)

# %%
n_grad.drop(['Were you able to rent an apartment or buy a car from the salary you got from your first job?','Thinking about your current employment, did you work for your employer before or during your  higher education study?','How do you find out about your job(s)?','Which sector is your most preferred sector to work in?'],axis=1,inplace=True)

# %%
n_grad.shape
# Out:
# (5219, 28)

# %%
n_grad
# Out:
#                Timestamp What is your gender  Year of graduation  \
# 0       2/8/2018 9:05:23                Male                2013
# 1     2/15/2018 12:11:32                Male                2014
# 2     2/15/2018 13:47:10              Female                2013
# 3     2/16/2018 13:01:34                Male                2017
# 4     2/16/2018 13:18:03              Female                2013
# ...                  ...                 ...                 ...
# 5214  5/14/2018 19:51:56              Female                2014
# 5215  5/15/2018 10:17:12              Female                2017
# 5216  5/15/2018 10:33:45              Female                2014
# 5217  5/15/2018 13:49:47              Female                2015
# 5218  5/15/2018 23:39:09                Male                2016
#
#                                 Title of course studied  \
# 0                   Electrical & Electronic Engineering
# 1                                            Psychology
# ...

# %%
n_grad.drop(['Did you get your first full time job through your NYSC placement?','Reason why?','Which form of transport do you use the most?'],axis=1,inplace=True)

# %%
n_grad.shape
# Out:
# (5219, 25)

# %%
n_grad.count()
# Out:
# Timestamp                                                                                                                       5219
# What is your gender                                                                                                             5219
# Year of graduation                                                                                                              5219
# Title of course studied                                                                                                         5219
# Polytechnic/University attended                                                                                                 5219
# What is your highest level of education?                                                                                        5219
# What best describes your current status?                                                                                        5219
# ...

# %%
n_grad.drop('Timestamp',axis=1,inplace=True)

# %%
n_grad.shape
# Out:
# (5219, 24)

# %%
n_grad.count()
# Out:
# What is your gender                                                                                                             5219
# Year of graduation                                                                                                              5219
# Title of course studied                                                                                                         5219
# Polytechnic/University attended                                                                                                 5219
# What is your highest level of education?                                                                                        5219
# What best describes your current status?                                                                                        5219
# Have you completed your NYSC?                                                                                                   5218
# ...

# %%
n_grad
# Out:
#      What is your gender  Year of graduation  \
# 0                   Male                2013
# 1                   Male                2014
# 2                 Female                2013
# 3                   Male                2017
# 4                 Female                2013
# ...                  ...                 ...
# 5214              Female                2014
# 5215              Female                2017
# 5216              Female                2014
# 5217              Female                2015
# 5218                Male                2016
#
#                                 Title of course studied  \
# 0                   Electrical & Electronic Engineering
# 1                                            Psychology
# 2                                             Economics
# 3     Mass Communication (Communication and Language...
# 4                                            Statistics
# ...                                                 ...
# ...

# %%
n_grad.isnull()
# Out:
#       What is your gender  Year of graduation  Title of course studied  \
# 0                   False               False                    False
# 1                   False               False                    False
# 2                   False               False                    False
# 3                   False               False                    False
# 4                   False               False                    False
# ...                   ...                 ...                      ...
# 5214                False               False                    False
# 5215                False               False                    False
# 5216                False               False                    False
# 5217                False               False                    False
# 5218                False               False                    False
#
#       Polytechnic/University attended  \
# 0                               False
# ...

# %%
n_grad.isnull().any()
# Out:
# What is your gender                                                                                                             False
# Year of graduation                                                                                                              False
# Title of course studied                                                                                                         False
# Polytechnic/University attended                                                                                                 False
# What is your highest level of education?                                                                                        False
# What best describes your current status?                                                                                        False
# Have you completed your NYSC?                                                                                                    True
# ...

# %%
n_grad.isnull().sum()
# Out:
# What is your gender                                                                                                                0
# Year of graduation                                                                                                                 0
# Title of course studied                                                                                                            0
# Polytechnic/University attended                                                                                                    0
# What is your highest level of education?                                                                                           0
# What best describes your current status?                                                                                           0
# Have you completed your NYSC?                                                                                                      1
# ...

# %%
n_grad=n_grad.dropna()

# %%
n_grad.head()
# Out:
#    What is your gender  Year of graduation  \
# 4               Female                2013
# 5                 Male                2015
# 6                 Male                2013
# 8               Female                2017
# 10                Male                2015
#
#                           Title of course studied  \
# 4                                      Statistics
# 5             Electrical & Electronic Engineering
# 6                                       Economics
# 8   Industrial Relations and Personnel Management
# 10                                      Economics
#
#    Polytechnic/University attended What is your highest level of education?  \
# 4           Ekiti State University                        Bachelor's degree
# 5              University of Benin                        Bachelor's degree
# 6            Bowen University, Iwo            Higher National Diploma (HND)
# 8          Covenant University Ota                        Bachelor's degree
# ...

# %%
plt.figure(figsize = (15, 18))

jobs=sns.countplot(y='What is your job role?',hue='What is your gender',data=n_grad)

plt.savefig('jobs.png')

# %%
plt.figure(figsize = (15, 6))

income=sns.countplot(x='What is your current monthly income level?',hue='What is your gender',data=n_grad)
plt.savefig('income.png')

# %%
gender = sns.countplot(x='What is your gender',data=n_grad)

plt.savefig('gender.png')

# %%
plt.figure(figsize = (11, 30))

course = sns.countplot(y='Title of course studied',hue='What is your gender',data=n_grad)

plt.savefig('course.png')

# %%
plt.figure(figsize = (11, 15))

sector = sns.countplot(y='What sector/industry is your company in? (E.g. Banking, Agriculture, Telecommunication)',hue='What is your gender',data=n_grad)

plt.savefig('sector.png')

# %%
plt.figure(figsize = (10, 5))

satisfaction = sns.countplot(y='My course of study prepared me well for employment',hue='What is your gender',data=n_grad)

plt.savefig('satisfaction.png')

# %%
n_grad.shape
# Out:
# (1279, 24)

# %%
n_grad.isnull().sum()
# Out:
# What is your gender                                                                                                             0
# Year of graduation                                                                                                              0
# Title of course studied                                                                                                         0
# Polytechnic/University attended                                                                                                 0
# What is your highest level of education?                                                                                        0
# What best describes your current status?                                                                                        0
# Have you completed your NYSC?                                                                                                   0
# ...

# %%
n_grad.isnull().sum().sum()
# Out:
# 0

# %%
n_grad.count()
# Out:
# What is your gender                                                                                                             1279
# Year of graduation                                                                                                              1279
# Title of course studied                                                                                                         1279
# Polytechnic/University attended                                                                                                 1279
# What is your highest level of education?                                                                                        1279
# What best describes your current status?                                                                                        1279
# Have you completed your NYSC?                                                                                                   1279
# ...

# %%
gen_level=n_grad[['What is your gender','What is your highest level of education?']]
gen_level.head()
# Out:
#    What is your gender What is your highest level of education?
# 4               Female                        Bachelor's degree
# 5                 Male                        Bachelor's degree
# 6                 Male            Higher National Diploma (HND)
# 8               Female                        Bachelor's degree
# 10                Male                        Bachelor's degree

# %%
gen_level.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1279 entries, 4 to 5217
# Data columns (total 2 columns):
# What is your gender                         1279 non-null object
# What is your highest level of education?    1279 non-null object
# dtypes: object(2)
# memory usage: 70.0+ KB

# %%
male_grad=gen_level[gen_level['What is your gender'] == 'Male']['What is your highest level of education?'].value_counts()

# %%
female_grad=gen_level[gen_level['What is your gender'] == 'Female']['What is your highest level of education?'].value_counts()

# %%
male_grad
# Out:
# Bachelor's degree                  544
# Master's degree                     64
# Higher National Diploma (HND)       46
# Ordinary National Diploma (OND)      5
# MBA degree                           4
# PhDs/Doctorate Degree                1
# Name: What is your highest level of education?, dtype: int64

# %%
male_grad.plot.bar()

# %%
female_grad.plot.bar()

# %%
plt.plot(male_grad,female_grad)

# %%
gen_level_job=n_grad[['What is your gender','What is your highest level of education?','What best describes your current status?']]

# %%
n_grad['What best describes your current status?'].unique()
# Out:
# array(['Working full time (paid employment)', 'Youth Corper (NYSC)',
#        'Due to start a job in the next month/developing a professional portfolio/creative practice',
#        'Voluntary or other unpaid work or on an internship',
#        'Self-employed/freelance/entrepreneur',
#        'Engaged in full-time further study, training or research',
#        'Taking time out to prepare for further studies, GMAT, professional exams',
#        'Unemployed',
#        'Engaged in part-time further study, training or research',
#        'Doing something else (e.g. looking after home or family)'],
#       dtype=object)

# %%
gen_level_job
# Out:
#      What is your gender What is your highest level of education?  \
# 4                 Female                        Bachelor's degree
# 5                   Male                        Bachelor's degree
# 6                   Male            Higher National Diploma (HND)
# 8                 Female                        Bachelor's degree
# 10                  Male                        Bachelor's degree
# ...                  ...                                      ...
# 5196                Male            Higher National Diploma (HND)
# 5204              Female                        Bachelor's degree
# 5208                Male                        Bachelor's degree
# 5211              Female                        Bachelor's degree
# 5217              Female            Higher National Diploma (HND)
#
#                What best describes your current status?
# 4                   Working full time (paid employment)
# 5                   Working full time (paid employment)
# ...

# %%
male_grad_job=gen_level_job[gen_level_job['What is your gender'] == 'Male']['What best describes your current status?'].value_counts()

# %%
male_grad_job
# Out:
# Working full time (paid employment)                                                           332
# Self-employed/freelance/entrepreneur                                                           90
# Youth Corper (NYSC)                                                                            66
# Unemployed                                                                                     62
# Voluntary or other unpaid work or on an internship                                             53
# Due to start a job in the next month/developing a professional portfolio/creative practice     23
# Engaged in full-time further study, training or research                                       17
# Taking time out to prepare for further studies, GMAT, professional exams                       11
# Doing something else (e.g. looking after home or family)                                        5
# Engaged in part-time further study, training or research                                        5
# ...

# %%
female_grad_job=gen_level_job[gen_level_job['What is your gender'] == 'Female']['What best describes your current status?'].value_counts()

# %%
female_grad_job
# Out:
# Working full time (paid employment)                                                           277
# Youth Corper (NYSC)                                                                           102
# Self-employed/freelance/entrepreneur                                                           77
# Unemployed                                                                                     62
# Voluntary or other unpaid work or on an internship                                             36
# Engaged in full-time further study, training or research                                       21
# Due to start a job in the next month/developing a professional portfolio/creative practice     14
# Taking time out to prepare for further studies, GMAT, professional exams                       12
# Doing something else (e.g. looking after home or family)                                       11
# Engaged in part-time further study, training or research                                        3
# ...

# %%
male_grad_job.plot.bar()

# %%
female_grad_job.plot.bar()
