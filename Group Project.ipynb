# %% [markdown]
# # Import Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('Nigerian Graduates.csv')

# %%
df1.head()
# Out:
#             Timestamp What is your gender  Year of graduation  \
# 0    2/8/2018 9:05:23                Male                2013
# 1  2/15/2018 12:11:32                Male                2014
# 2  2/15/2018 13:47:10              Female                2013
# 3  2/16/2018 13:01:34                Male                2017
# 4  2/16/2018 13:18:03              Female                2013
#
#                              Title of course studied  \
# 0                Electrical & Electronic Engineering
# 1                                         Psychology
# 2                                          Economics
# 3  Mass Communication (Communication and Language...
# 4                                         Statistics
#
#         Polytechnic/University attended  \
# 0    Obafemi Awolowo University,Ile-Ife
# 1    Obafemi Awolowo University,Ile-Ife
# 2  Bells University of Technology, Otta
# 3                 Bowen University, Iwo
# 4                Ekiti State University
#
# ...

# %%
df1.describe()
# Out:
#        Year of graduation  \
# count         5219.000000
# mean          2015.329182
# std              1.305153
# min           2013.000000
# 25%           2014.000000
# 50%           2015.000000
# 75%           2016.000000
# max           2017.000000
#
#        How many jobs have you had since graduation including your current one?  \
# count                                        5219.000000
# mean                                            1.136999
# std                                             1.140146
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             1.000000
# 75%                                             2.000000
# max                                            10.000000
#
#        If you answered yes/ongoing to the previous question, what year did you (or will you) complete your NYSC?  \
# count                                        4278.000000
# ...

# %%
df1.count()
# Out:
# Timestamp                                                                                                                       5219
# What is your gender                                                                                                             5219
# Year of graduation                                                                                                              5219
# Title of course studied                                                                                                         5219
# Polytechnic/University attended                                                                                                 5219
# What is your highest level of education?                                                                                        5219
# What best describes your current status?                                                                                        5219
# ...

# %%
df1.tail()
# Out:
#                Timestamp What is your gender  Year of graduation  \
# 5214  5/14/2018 19:51:56              Female                2014
# 5215  5/15/2018 10:17:12              Female                2017
# 5216  5/15/2018 10:33:45              Female                2014
# 5217  5/15/2018 13:49:47              Female                2015
# 5218  5/15/2018 23:39:09                Male                2016
#
#       Title of course studied             Polytechnic/University attended  \
# 5214    Physics and Astronomy                         University of Lagos
# 5215         Acturial Science                         University of Lagos
# 5216        Political Science       Others (For foreign trained students)
# 5217  Business Administration  The Polytechnic Ibadan, Ibadab, Oyo State.
# 5218                Economics                Usumanu Danfodiyo University
#
#      What is your highest level of education?  \
# 5214                        Bachelor's degree
# ...

# %%
list(df1.columns.values.tolist())
# Out:
# ['Timestamp',
#  'What is your gender',
#  'Year of graduation',
#  'Title of course studied',
#  'Polytechnic/University attended',
#  'What is your highest level of education?',
#  'What best describes your current status?',
#  'How many jobs have you had since graduation including your current one?',
#  'Have you completed your NYSC?',
#  'If you answered yes/ongoing to the previous question, what year did you (or will you) complete your NYSC?',
#  'Did you get your first full time job through your NYSC placement?',
#  'Thinking about your first employment after graduation, what was your job level?',
#  'What is/was your job role?',
#  'What sector/industry is your company in? (E.g. Banking, Agriculture, Telecommunication)',
#  'Still thinking about your first employment, what is/was your monthly income level?',
#  'Did you need your higher education qualification to get your first job (the actual qualification, not the subject of study)?',
# ...

# %%
df2 = df1.loc[:, ['What is your gender', 'Title of course studied', 'What is your highest level of education?', 'If you answered yes/ongoing to the previous question, what year did you (or will you) complete your NYSC?', 'Thinking about your first employment after graduation, what was your job level?', 'Polytechnic/University attended', 'My course of study prepared me well for employment', 'What is your current monthly income level?', 'Which of these skills/knowledge did your higher education prepare you for?', 'Which sector is your most preferred sector to work in?']]

# %%
df2.head()
# Out:
#   What is your gender                            Title of course studied  \
# 0                Male                Electrical & Electronic Engineering
# 1                Male                                         Psychology
# 2              Female                                          Economics
# 3                Male  Mass Communication (Communication and Language...
# 4              Female                                         Statistics
#
#   What is your highest level of education?  \
# 0                        Bachelor's degree
# 1                        Bachelor's degree
# 2                        Bachelor's degree
# 3                          Master's degree
# 4                        Bachelor's degree
#
#    If you answered yes/ongoing to the previous question, what year did you (or will you) complete your NYSC?  \
# 0                                                NaN
# 1                                             2017.0
# ...

# %%
df2.count()
# Out:
# What is your gender                                                                                          5219
# Title of course studied                                                                                      5219
# What is your highest level of education?                                                                     5219
# If you answered yes/ongoing to the previous question, what year did you (or will you) complete your NYSC?    4278
# Thinking about your first employment after graduation, what was your job level?                              1656
# Polytechnic/University attended                                                                              5219
# My course of study prepared me well for employment                                                           3432
# What is your current monthly income level?                                                                   3432
# ...

# %%
Level_of_Education = [df2['What is your gender'] == 'Male']['What is your highest level of education?'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-cfb6d7e69889> in <module>
# ----> 1 Level_of_Education = [df2['What is your gender'] == 'Male']['What is your highest level of education?'].value_counts()
#
# TypeError: list indices must be integers or slices, not str

# %%
Level_of_Education = df1[['What is your gender','What is your highest level of education?']]
Level_of_Education
# Out:
#      What is your gender What is your highest level of education?
# 0                   Male                        Bachelor's degree
# 1                   Male                        Bachelor's degree
# 2                 Female                        Bachelor's degree
# 3                   Male                          Master's degree
# 4                 Female                        Bachelor's degree
# ...                  ...                                      ...
# 5214              Female                        Bachelor's degree
# 5215              Female                        Bachelor's degree
# 5216              Female                        Bachelor's degree
# 5217              Female            Higher National Diploma (HND)
# 5218                Male                        Bachelor's degree
#
# [5219 rows x 2 columns]

# %%
Male_grad = df2[df2['What is your gender'] == 'Male']['What is your highest level of education?'].value_counts()
Male_grad
# Out:
# Bachelor's degree                  2158
# Higher National Diploma (HND)       210
# Master's degree                     191
# Ordinary National Diploma (OND)      53
# MBA degree                            9
# PhDs/Doctorate Degree                 3
# Name: What is your highest level of education?, dtype: int64

# %%
Female_grad = df2[df2['What is your gender'] == 'Female']['What is your highest level of education?'].value_counts()
Female_grad
# Out:
# Bachelor's degree                  2241
# Higher National Diploma (HND)       158
# Master's degree                     115
# Ordinary National Diploma (OND)      63
# MBA degree                           11
# PhDs/Doctorate Degree                 4
# Name: What is your highest level of education?, dtype: int64

# %%
Male_grad.plot.bar()

# %%
Female_grad.plot.bar()

# %%
plt.figure(figsize = (12,8))
plt.subplot(1,2,1)
Male_grad.plot.bar()

plt.subplot(1,2,2)
Female_grad.plot.bar()

# %%
Male_grad, Female_grad.plot.bar()
# Out:
# (Bachelor's degree                  2158
#  Higher National Diploma (HND)       210
#  Master's degree                     191
#  Ordinary National Diploma (OND)      53
#  MBA degree                            9
#  PhDs/Doctorate Degree                 3
#  Name: What is your highest level of education?, dtype: int64,
#  <matplotlib.axes._subplots.AxesSubplot at 0xe9d1f9ac50>)

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=5219, step=1)

# %%
df3 = df1.iloc[[2,6,10,12,5,4,34,21,26,36]]

# %%
df3.head(10)
# Out:
#              Timestamp What is your gender  Year of graduation  \
# 2   2/15/2018 13:47:10              Female                2013
# 6    2/19/2018 7:24:05                Male                2013
# 10   2/19/2018 9:19:58                Male                2015
# 12  2/19/2018 10:39:41                Male                2017
# 5   2/16/2018 16:44:18                Male                2015
# 4   2/16/2018 13:18:03              Female                2013
# 34  2/20/2018 14:38:40                Male                2015
# 21   2/20/2018 0:46:02                Male                2016
# 26  2/20/2018 12:51:16              Female                2017
# 36  2/20/2018 14:45:13                Male                2016
#
#                 Title of course studied  \
# 2                             Economics
# 6                             Economics
# 10                            Economics
# 12        Petroleum and Gas Engineering
# 5   Electrical & Electronic Engineering
# ...

# %%
sns.c
